# %% [markdown]
# # Evaluation and Ablation Notebook
#
# This notebook focuses on benchmarking the defense pipeline against a no-defense baseline. The aim is to make the evaluation story explicit and reproducible.

# %%
from ragdefense.evaluation import build_benchmark_summary, compute_classification_metrics
print(build_benchmark_summary())
print(compute_classification_metrics(tp=19, fp=1, tn=80, fn=0))
